# %%
#
#
#      Hi, welcome to the home of our assignment 2! 
#                                              -- Saravana Subbiah & Lin Xiongtao
#
#
#      The theme of our data is "Customer Complaints in Financial Services in U.S.".
#          The data is mainly from data.gov, census.gov and topsy.com.
#              Please feel free to play with any data in this notebook.
#
#

# %%
# Use boto to get the data saved in Amazon S3 with Access Key.
import boto
s3 = boto.connect_s3("AKIAJ4ATBBYHPUMEZOUQ","arPAmwUzS9QVXNS6ne8g4zx85/bMfs6xw6+pILWP")
key = s3.get_bucket('bigdataassign').get_key('Consumer_Complaints.csv')
key.get_contents_to_filename('Consumer_Complaints.csv')

# %%
# Set graph display options and read the data.
import pandas as pd
pd.set_option('display.mpl_style', 'default') 
pd.set_option('display.line_width', 5000) 
pd.set_option('display.max_columns', 60) 
d=pd.read_csv("Consumer_Complaints.csv",parse_dates=['Date received'], index_col='Date received')
# Out:
# line_width has been deprecated, use display.width instead (currently both are
# identical)
# /home/ubuntu/anaconda/lib/python2.7/site-packages/pandas/io/parsers.py:1130: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)

# %%
# Understand the structure of the data.
d.head(2)
# Out:
#                Complaint ID          Product  Sub-product                  Issue                                Sub-issue State  ZIP code Submitted via Date sent to company                         Company         Company response Timely response? Consumer disputed?
# Date received
# 2014-09-26          1046495  Debt collection  Credit card  Communication tactics          Threatened to take legal action    PA     15227           Web           09/26/2014     Premium Asset Services, LLC              In progress              Yes                NaN
# 2014-09-26          1046671  Debt collection  Payday loan  Communication tactics  Called after sent written cease of comm    OH     45068           Web           09/26/2014  National Credit Adjusters, LLC  Closed with explanation              Yes                NaN

# %%
# Total complaints of each kind of products.
figsize(10, 5)
ProductWise=d['Product'].value_counts()
ProductWise.reindex(index=ProductWise.index[::-1]).plot(kind="barh",title="Total complaints of each kind of products")

# %%
# Total complaints of top 20 issues.
figsize(10, 5)
IssueWise=d['Issue'].value_counts()[:20]
IssueWise.reindex(index=IssueWise.index[::-1]).plot(kind="barh",title="Total complaints of top 20 issues")

# %%
# Total complaints of top 20 sub issues.
figsize(10, 5)
SubIssueWise=d['Sub-issue'].value_counts()[:20]
SubIssueWise.reindex(index=SubIssueWise.index[::-1]).plot(kind="barh",title="Total complaints of top 20 sub issues")

# %%
# Total complaints of each channel
figsize(8, 3)
ChannelWise=d['Submitted via'].value_counts()
ChannelWise.reindex(index=ChannelWise.index[::-1]).plot(kind="barh",title="Total complaints of each channel")

# %%
# Total complaints of each company
figsize(10, 5)
CompanyWise=d['Company'].value_counts()[:20]
CompanyWise.reindex(index=CompanyWise.index[::-1]).plot(kind="barh",title="Total complaints of each company")

# %%
# Response Status
figsize(8, 8)
d['Company response'].value_counts().plot(kind="pie",title="Response Status")

# %%
# Customer Disputed?
figsize(3, 3)
d['Consumer disputed?'].value_counts().plot(kind="pie",title="Customer Disputed?")

# %%
# Timely Response Rate
figsize(7, 6)
TimelyResponse=d['Timely response?']=='Yes'
TimelyResponse.astype(float).resample('M',how=np.mean).plot(title="Timely Response Rate")

# %%
# Customer Disputed Rate
figsize(7, 6)
CustomerDisputed=d['Consumer disputed?']=='Yes'
CustomerDisputed.astype(float).resample('M',how=np.mean).plot(title="Customer Disputed Rate")

# %%
#Correlation between TimelyResponseRate and CustomerDisputedRate
TimelyResponseRate=TimelyResponse.astype(float).resample('M',how=np.mean)
CustomerDisputedRate=CustomerDisputed.astype(float).resample('M',how=np.mean)
TimelyResponseRate.corr(CustomerDisputedRate)
# Out:
# -0.42457289781948193

# %%
# IssueAmount
IssueAmount=d.resample('M',how=count)[1:34]['Product']
IssueAmount.plot(title="Trend of issues amount")

# %%
# Complaints Per Day: Credit Card
d[d['Product']=="Credit card"].resample('D',how=count)['Product'].tail(26).plot(title="Complaints Per Day: Credit card")

# %%
# Complaints received per year
figsize(6,6)
YearWise=d.resample('A',how=count)['Product']
YearWise[3]=YearWise[3]/0.7342
YearWise.plot(title="Complaints received per year")

# %%
Area['Credit card']=d[d['Product']=="Credit card"].resample('M',how=count)['Product']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-243-71fa38e11503> in <module>()
# ----> 1 Area['Credit card']=d[d['Product']=="Credit card"].resample('M',how=count)['Product']
#
# NameError: name 'Area' is not defined

# %%
figsize(10,10)
Area=pd.DataFrame(index=d[d['Product']=="Credit card"].resample('M',how=count).index)
Area['Mortgage']=d[d['Product']=="Mortgage"].resample('M',how=count)['Product']
Area['Credit card ']=d[d['Product']=="Credit card "].resample('M',how=count)['Product']
Area['Debt collection']=d[d['Product']=="Debt collection"].resample('M',how=count)['Product']
Area['Credit reporting']=d[d['Product']=="Credit reporting"].resample('M',how=count)['Product']
Area['Bank account or service']=d[d['Product']=="Bank account or service"].resample('M',how=count)['Product']
Area['Student loan']=d[d['Product']=="Student loan"].resample('M',how=count)['Product']
Area['Consumer loan']=d[d['Product']=="Consumer loan"].resample('M',how=count)['Product']
Area['Money transfers']=d[d['Product']=="Money transfers"].resample('M',how=count)['Product']
Area['Payday loan']=d[d['Product']=="Payday loan"].resample('M',how=count)['Product']
Area.plot(kind="area")

# %%
d['Product'].value_counts()
# Out:
# Mortgage                   120237
# Credit card                 39874
# Debt collection             39547
# Credit reporting            37334
# Bank account or service     36170
# Student loan                 8871
# Consumer loan                8555
# Money transfers              1401
# Payday loan                  1339
# dtype: int64
